# %% [markdown]
# # Diferencias finitas: cálculo numérico de derivadas

# %% [markdown]
# En el último notebook, vimos que el método de Newton requiere conocer la derivada de una función.
# En este notebook, veremos una manera (no necesariamente la mejor) de calcular derivadas de funciones de forma numérica: las llamadas **diferencias finitas**.

# %% [markdown]
# ## Derivadas de funciones uni-dimensionales

# %% [markdown]
# [1] Considera una función uni-dimensional $f: \mathbb{R} \to \mathbb{R}$, y supón que es suficientemente diferenciable para que las derivadas que tomemos estén definidas [por ejemplo, de clase $C^2$].
#
# Escribe, usando notación LaTeX, la definición de la derivada $f'(a)$ de $f$ en el punto $a$, como límite cuando la variable $h$ tiende a $0$.

# %% [markdown]
# $$ f'(a) = \lim_{h\to 0} \frac{f(a+h) - f(a)}{h} $$

# %% [markdown]
# [2] Desgraciadamente, **no podemos llevar a cabo el proceso de límite en la computadora**. (Intuitivamente, podemos decir que el proceso de límite es **continuo**, mientras que la computadora maneja cantidades **discretas**.)
#
# (i) ¿Cuál solución se te ocurre para esto en términos de la variable $h$?
#
# La expresión $f(a+h) - f(a)$ se llama una **diferencia para adelante** ("forward difference"), y cuando lo dividimos por $h$ se llama un **cociente de diferencias** ("difference quotient").
#
# (ii) ¿Geométricamente, a qué corresponde una diferencia de este tipo? ¿Y un cociente de diferencias?

# %% [markdown]
# **R:** (i) Hacer este proceso dentro de un for, con h muy pequeñas, tendiendo a cero.
#
# (ii) Una diferencia para adelante es qué tanto varía la imagen de la función al modificar el argumento un paso muy chiquito. El cociente de diferencias nos dice qué tanto varía la imagen de la función en un paso chiquito con respecto a un paso chiquito en el argumento.

# %% [markdown]
# [3] (i) Escribe una función que implemente una diferencia para adelante para una función $f$, punto $a$ y paso $h$ dadas.
#
# (ii) Para distintas funciones $f$, grafica la función $f$, su derivada analítica $f'$, y la aproximación a $f'$ usando diferencias finitas.

# %%
###(i)
function forw_diff(f::Function, a::Float64,h::Float64 = 0.00001)
   forw_diff = f(a + h) - f(a)
    return forw_diff
end

forw_diff(x -> 2x^2 - 1,2.0,0.001)
# Out:
# 0.008001999999999398

# %%
g(x) = 3x^3 - 2x^2 + x + 3
dg(x) = 9x^2 - 4x + 1
# Out:
# dg (generic function with 1 method)

# %%
function derivada_en_a(f::Function, a::Float64, h::Float64 = 0.00001)
   deriv = forw_diff(f, a, h)/h
    return deriv
end

 """ Calcula la derivada de una función f en un intervalo."""
function derivada(f::Function, rango, h::Float64 = 0.00001)
    df=Float64[]
    for a in rango
        df_a = derivada_en_a(f,a,h)
        push!(df,df_a)
    end
    return df
end
# Out:
# derivada

# %%
using Plots
gr();

# %%
rango1 = collect(-5.0:0.1:5.0)

plot(rango1,g)
plot!(rango1, dg)
scatter!(rango1, derivada(g,rango1), markersize=1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 596.063,384.952 596.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="557" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   107.751,379.237 107.751,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   212.764,379.237 212.764,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   317.778,379.237 317.778,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   422.791,379.237 422.791,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   527.804,379.237 527.804,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,290.455 587.714,290.455
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,172.215 587.714,172.215
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,53.976 587.714,53.976
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   107.751,384.952 107.751,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   212.764,384.952 212.764,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   317.778,384.952 317.778,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   422.791,384.952 422.791,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   527.804,384.952 527.804,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 39.4926,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,290.455 47.8411,290.455
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,172.215 47.8411,172.215
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,53.976 47.8411,53.976
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 107.751, 396.952)" x="107.751" y="396.952">-4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.764, 396.952)" x="212.764" y="396.952">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 317.778, 396.952)" x="317.778" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 422.791, 396.952)" x="422.791" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 527.804, 396.952)" x="527.804" y="396.952">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 294.955)" x="38.2926" y="294.955">-250</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 176.715)" x="38.2926" y="176.715">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 58.476)" x="38.2926" y="58.476">250</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   55.2446,374.168 60.4952,362.755 65.7459,351.777 70.9965,341.226 76.2472,331.095 81.4979,321.375 86.7485,312.056 91.9992,303.131 97.2499,294.59 102.501,286.427
#   107.751,278.631 113.002,271.195 118.253,264.109 123.503,257.366 128.754,250.957 134.005,244.874 139.255,239.107 144.506,233.648 149.757,228.49 155.007,223.623
#   160.258,219.038 165.509,214.728 170.759,210.684 176.01,206.897 181.261,203.359 186.511,200.061 191.762,196.995 197.012,194.152 202.263,191.523 207.514,189.101
#   212.764,186.877 218.015,184.842 223.266,182.988 228.516,181.305 233.767,179.787 239.018,178.423 244.268,177.206 249.519,176.127 254.77,175.178 260.02,174.35
#   265.271,173.634 270.522,173.023 275.772,172.507 281.023,172.078 286.274,171.727 291.524,171.447 296.775,171.228 302.026,171.062 307.276,170.94 312.527,170.855
#   317.778,170.797 323.028,170.757 328.279,170.728 333.53,170.701 338.78,170.668 344.031,170.619 349.282,170.547 354.532,170.442 359.783,170.297 365.034,170.103
#   370.284,169.851 375.535,169.532 380.786,169.139 386.036,168.663 391.287,168.095 396.538,167.427 401.788,166.65 407.039,165.755 412.29,164.735 417.54,163.581
#   422.791,162.283 428.042,160.835 433.292,159.226 438.543,157.449 443.794,155.495 449.044,153.356 454.295,151.023 459.546,148.488 464.796,145.741 470.047,142.775
#   475.298,139.581 480.548,136.151 485.799,132.476 491.05,128.547 496.3,124.356 501.551,119.894 506.802,115.154 512.052,110.126 517.303,104.802 522.554,99.1732
#   527.804,93.2315 533.055,86.9681 538.306,80.3746 543.556,73.4424 548.807,66.1631 554.058,58.5282 559.308,50.529 564.559,42.1572 569.81,33.4042 575.06,24.2614
#   580.311,14.7204
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#e9746a; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   55.2446,55.8678 60.4952,60.271 65.7459,64.5891 70.9965,68.8221 76.2472,72.9699 81.4979,77.0326 86.7485,81.0102 91.9992,84.9027 97.2499,88.71 102.501,92.4322
#   107.751,96.0692 113.002,99.6211 118.253,103.088 123.503,106.47 128.754,109.766 134.005,112.977 139.255,116.104 144.506,119.145 149.757,122.101 155.007,124.972
#   160.258,127.757 165.509,130.458 170.759,133.073 176.01,135.604 181.261,138.049 186.511,140.409 191.762,142.684 197.012,144.874 202.263,146.978 207.514,148.998
#   212.7

# %% [markdown]
# [4] (i) Calcula el error desde el valor analítico que se comete al utilizar la aproximación de la derivada al tomar una $f$ y $a$ dadas, y variar $h$, usando la función `logspace` para que los valores de $h$ estén espaciados de forma logarítmica. Hazlo para diferentes funciones. (¡Escribe una función que haga el cálculo!) ¿Qué podría causar este efecto?
#
# (ii) ¿Para qué clase de funciones será el resultado exacto? Demuéstralo gráficamente. Así, qué tipo de **aproximación local** de la función estamos usando?

# %%
##(i)
function errores_deriv(f::Function, df::Function, a::Float64)
    diferencia = 0.
    errores = Float64[]
    for h in logspace(-2,-30,100)
    diferencia = abs( df(a) - derivada_en_a(f,a,h) )
        push!(errores,diferencia)
    end
    return errores
end
# Out:
# errores_deriv (generic function with 1 method)

# %%
errores_deriv(g,dg,2.0);

# %%
rangolog = logspace(-2,-30,100);

# %%
plot(rangolog,errores_deriv(g,dg,2.0), xscale=:log10, yscale=:log10, marker=:auto)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 66.1592,384.952 596.063,384.952 596.063,3.93701 66.1592,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="66" y="3" width="530" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   66.1592,379.237 66.1592,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   255.411,379.237 255.411,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   444.662,379.237 444.662,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   74.1078,286.73 588.114,286.73
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   74.1078,177.331 588.114,177.331
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   74.1078,67.9312 588.114,67.9312
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,384.952 66.1592,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255.411,384.952 255.411,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   444.662,384.952 444.662,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,384.952 66.1592,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,286.73 74.1078,286.73
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,177.331 74.1078,177.331
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,67.9312 74.1078,67.9312
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 51.4037, 401.904)" x="51.4037" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 64.5829, 395.051)" x="64.5829" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 70.2066, 395.051)" x="70.2066" y="395.051">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 240.655, 401.904)" x="240.655" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 253.834, 395.051)" x="253.834" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 259.458, 395.051)" x="259.458" y="395.051">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 429.906, 401.904)" x="429.906" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 443.086, 395.051)" x="443.086" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 448.709, 395.051)" x="448.709" y="395.051">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7711, 292.662)" x="32.7711" y="292.662">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9503, 285.809)" x="45.9503" y="285.809">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.574, 285.809)" x="51.574" y="285.809">5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7711, 183.262)" x="32.7711" y="183.262">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9503, 176.41)" x="45.9503" y="176.41">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.574, 176.41)" x="51.574" y="176.41">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 38.3948, 73.8631)" x="38.3948" y="73.8631">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.574, 67.0105)" x="51.574" y="67.0105">0.0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,102.723 590.71,115.117 585.358,127.502 580.005,139.883 574.653,152.262 569.3,164.64 563.948,177.017 558.595,189.394 553.242,201.77 547.89,214.147
#   542.537,226.524 537.185,238.9 531.832,251.276 526.48,263.654 521.127,276.026 515.775,288.423 510.422,300.81 505.069,313.247 499.717,325.91 494.364,341.919
#   489.012,343.445 483.659,384.952 478.307,333.174 472.954,326.526 467.601,321.618 462.249,295.967 456.896,313.332 451.544,304.168 446.191,320.539 440.839,240.79
#   435.486,240.344 430.134,249.35 424.781,222.095 419.428,231.243 414.076,191.185 408.723,164.102 403.371,160.238 398.018,139.675 392.666,143.071 387.313,155.41
#   381.96,105.227 376.608,106.133 371.255,91.214 365.903,70.0309 360.55,88.9059 355.198,50.8523 349.845,43.8758 344.493,28.22

# %%
using Interact;
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>

# %%
@manipulate for fun in [log, g, sin, x-> 4x], dfun in [x->1/x, dg, cos, x-> 4]
    scatter(rangolog ,errores_deriv(fun,dfun,2.0), xscale=:log10, yscale=:log10, line=(:line,1), marker=(:auto,4))
end #las funciones y sus derivadas están por pares, hay que cambiar fun y dfun uno a uno para ver las gráficas
# Out:
# Interact.Options{:ToggleButtons,Function}(Signal{Function}(log, nactions=1),"fun",log,"log",Interact.OptionDict(DataStructures.OrderedDict{String,Function}("log"=>log,"g"=>g,"sin"=>sin,"#25"=>#25),Dict{Function,String}(Pair{Function,String}(log,"log"),Pair{Function,String}(sin,"sin"),Pair{Function,String}(g,"g"),Pair{Function,String}(#25,"#25"))),Any[],Any[],true,"horizontal")
# Interact.Options{:ToggleButtons,Function}(Signal{Function}(#26, nactions=1),"dfun",#26,"#26",Interact.OptionDict(DataStructures.OrderedDict{String,Function}("#26"=>#26,"dg"=>dg,"cos"=>cos,"#27"=>#27),Dict{Function,String}(Pair{Function,String}(dg,"dg"),Pair{Function,String}(#26,"#26"),Pair{Function,String}(#27,"#27"),Pair{Function,String}(cos,"cos"))),Any[],Any[],true,"horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 66.1592,384.952 596.063,384.952 596.063,3.93701 66.1592,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="66" y="3" width="530" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   66.1592,379.237 66.1592,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   255.411,379.237 255.411,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   444.662,379.237 444.662,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   74.1078,320.482 588.114,320.482
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   74.1078,210.555 588.114,210.555
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   74.1078,100.628 588.114,100.628
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,384.952 66.1592,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255.411,384.952 255.411,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   444.662,384.952 444.662,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,384.952 66.1592,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,320.482 74.1078,320.482
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,210.555 74.1078,210.555
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,100.628 74.1078,100.628
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 51.4037, 401.904)" x="51.4037" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 64.5829, 395.051)" x="64.5829" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 70.2066, 395.051)" x="70.2066" y="395.051">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 240.655, 401.904)" x="240.655" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 253.834, 395.051)" x="253.834" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 259.458, 395.051)" x="259.458" y="395.051">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 429.906, 401.904)" x="429.906" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 443.086, 395.051)" x="443.086" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 448.709, 395.051)" x="448.709" y="395.051">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7711, 326.414)" x="32.7711" y="326.414">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9503, 319.561)" x="45.9503" y="319.561">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.574, 319.561)" x="51.574" y="319.561">7.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7711, 216.487)" x="32.7711" y="216.487">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9503, 209.634)" x="45.9503" y="209.634">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.574, 209.634)" x="51.574" y="209.634">5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7711, 106.559)" x="32.7711" y="106.559">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9503, 99.7068)" x="45.9503" y="99.7068">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.574, 99.7068)" x="51.574" y="99.7068">2.5</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.1592,3.93701 71.5118,3.93701 76.8644,3.93701 82.2169,3.93701 87.5695,3.93701 92.922,3.93701 98.2746,3.93701 103.627,3.93701 108.98,3.93701 114.332,3.93701
#   119.685,3.93701 125.037,3.93701 130.39,3.93701 135.743,3.93701 141.095,3.93701 146.448,3.93701 151.8,3.93701 157.153,3.93701 162.505,3.93701 167.858,3.93701
#   173.21,3.93701 178.563,3.93701 183.916,3.93701 189.268,3.93701 194.621,3.93701 199.973,3.93701 205.326,3.93701 210.678,3.93701 216.031,3.93701 221.384,3.93701
#   226.736,3.93701 232.089,3.9370

# %%
##(ii)
rangolog2 = logspace(-2,-60,100)
@manipulate for fun in [x-> 7x, x->5x + 6 , x->23x + 1.43, x-> 4x], dfun in [x->7, x->5, x->23, x-> 4]
    scatter(rangolog2 ,errores_deriv(fun,dfun,2.0), xscale=:log10, yscale=:log10, line=(:line,1), marker=(:auto,4))
end
# Out:
# Interact.Options{:ToggleButtons,Function}(Signal{Function}(#33, nactions=1),"fun",#33,"#33",Interact.OptionDict(DataStructures.OrderedDict{String,Function}("#33"=>#33,"#34"=>#34,"#35"=>#35,"#36"=>#36),Dict{Function,String}(Pair{Function,String}(#35,"#35"),Pair{Function,String}(#36,"#36"),Pair{Function,String}(#34,"#34"),Pair{Function,String}(#33,"#33"))),Any[],Any[],true,"horizontal")
# Interact.Options{:ToggleButtons,Function}(Signal{Function}(#37, nactions=1),"dfun",#37,"#37",Interact.OptionDict(DataStructures.OrderedDict{String,Function}("#37"=>#37,"#38"=>#38,"#39"=>#39,"#40"=>#40),Dict{Function,String}(Pair{Function,String}(#37,"#37"),Pair{Function,String}(#39,"#39"),Pair{Function,String}(#40,"#40"),Pair{Function,String}(#38,"#38"))),Any[],Any[],true,"horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 57.2703,384.952 596.063,384.952 596.063,3.93701 57.2703,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="57" y="3" width="539" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   57.2703,379.237 57.2703,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   150.166,379.237 150.166,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   243.061,379.237 243.061,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   335.956,379.237 335.956,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   428.851,379.237 428.851,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   521.747,379.237 521.747,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,302.509 587.981,302.509
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,164.856 587.981,164.856
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,27.2031 587.981,27.2031
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 57.2703,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   150.166,384.952 150.166,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   243.061,384.952 243.061,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   335.956,384.952 335.956,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   428.851,384.952 428.851,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   521.747,384.952 521.747,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 57.2703,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,302.509 65.3522,302.509
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,164.856 65.3522,164.856
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,27.2031 65.3522,27.2031
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 42.5148, 401.904)" x="42.5148" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.694, 395.051)" x="55.694" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 61.3177, 395.051)" x="61.3177" y="395.051">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 135.41, 401.904)" x="135.41" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 148.589, 395.051)" x="148.589" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 154.213, 395.051)" x="154.213" y="395.051">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 228.305, 401.904)" x="228.305" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 241.485, 395.051)" x="241.485" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 247.108, 395.051)" x="247.108" y="395.051">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 321.201, 401.904)" x="321.201" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 334.38, 395.051)" x="334.38" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 340.004, 395.051)" x="340.004" y="395.051">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 414.096, 401.904)" x="414.096" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 427.275, 395.051)" x="427.275" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 432.899, 395.051)" x="432.899" y="395.051">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 506.991, 401.904)" x="506.991" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neu

# %% [markdown]
# Como podemos ver en las gráficas de arriba el resultado se sigue aproximando para muchos órdenes de magnitud por debajo del punto óptimo para las demás funciones (no explota debido a error numérico), pero esto sólo se cumple para funciones lineales para las cuales una diferencia hacia adelante es el resultado exacto. Esto nos dice que estamos usando una aproximación local lineal de las funciones.

# %% [markdown]
# [5] (i) Desarrolla $f(a + h)$ en una serie de Taylor con término complementario de Lagrange. Así, rederiva la expresión aproximada que ya obtuviste para la derivada, pero ahora con información *analítica* sobre **el tamaño del error** que cometes cuando utilizas esta aproximación (asintóticamente cuando $h \to 0$). Si el error va como $C.h^n$, con $C$ una constante, entonces escribimos $\mathcal{O}(h^n)$.

# %% [markdown]
# (ii) Verifica que coinicide con lo que encontraste numéricamente.

# %% [markdown]
# [6] Una mejor aproximación (¿a qué nos referimos con eso?) es la **diferencia centrada**: expande $f(a+h)$ y $f(a - h)$ en series de Taylor separadas. Así, deriva una mejor aproximación a la primera derivada. Calcula su error y chécalo numéricamente.  ¿Para qué tipo de funciones es exacta?

# %% [markdown]
# [7] Encuentra una aproximación para la segunda derivada y encuentra su error; chécalo numéricamente.

# %% [markdown]
# ## Funciones multi-dimensionales

# %% [markdown]
# Ahora consideremos una función $f: \mathbb{R}^2 \to \mathbb{R}$ y $g: \mathbb{R}^2 \to \mathbb{R}^2$.

# %% [markdown]
# [8] ¿Qué tipo de derivadas quisiéramos poder calcular para $f$ y $g$? ¿Cómo podemos utilizar lo que ya hicimos para funciones uni-dimensionales para aplicarlo directamente a $f$ y $g$?

# %% [markdown]
# Para $f$ y $g$ lo primero que querríamos calcular son sus derivadas parciales $\frac{\partial f}{\partial x_i}$ ó $\frac{\partial g_i}{\partial x_j}$ respectivamente, para así poder construir otros tipos de derivadas, ya sea el gradiente, la divergencia, el rotacional, el laplaciano, etc. .

# %% [markdown]
# [9] Impleméntalo y compara con funciones cuyas derivadas conoces analíticamente.

# %% [markdown]
# ## De regreso al método de Newton

# %% [markdown]
# [10] Utiliza una diferencia finita, con una $h$ pequeña, para aproximar la derivada en el método de Newton. ¿Cómo afecta el utilizar una aproximación de la derivada, en lugar del valor exacto, en la tasa de convergencia? Compara los resultados al utilizar los dos tipos de diferencias finitas (para adelante y centrada).

# %% [markdown]
# ## Optimización

# %% [markdown]
# Una tarea importante es la **optimización**, es decir, encontrar máximos y mínimos de funciones.
#
# [11] Escribe una función que toma una función $f:\mathbb{R} \to \mathbb{R}$ lisa (es decir, suficientemente diferenciable), y utiliza lo que hemos visto para encontrar:
# (i) los valores de $x$ en los cuales la función toma su valor máximo y mínimo;
# (ii) el valor ahí;
# (iii) si es un máximo o un mínimo.
#
# [Pista: ¿Cuáles son las condiciones matemáticas que se deben cumplir para (i) y (iii)?]
