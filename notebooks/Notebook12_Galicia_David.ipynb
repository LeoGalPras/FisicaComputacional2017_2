# %% [markdown]
# # Euler puede fracasar: sistemas con una ley de conservación

# %% [markdown]
# El método de Euler parece sencillo y útil, pero puede fracasar; de hecho, resulta que *casi siempre fracasa*, no sólo cuantitativamente, sino también cualitativamente.
#
# Por ejemplo, consideremos la ecuación del péndulo para ángulos pequeños, o sea, un oscilador armónico simple.
#
# **[1]** (i) Escribe la ecuación de movimiento del oscilador armónico simple, en términos del ángulo $\theta$ del péndulo desde el vertical, y la velocidad angular $\omega$.

# %% [markdown]
# Para un péndulo aproximado por $\sin \theta \approx \theta $ tenemos que la ecuación de movimiento es:
#
# $$ \ddot{\theta}(t) =  -\frac{g}{L}\theta (t) = -{\omega_{0} ^2} \theta (t) $$
#
# con $L$ la longitud del peńdulo y $g$ la aceleración de la gravedad (véase https://es.wikipedia.org/wiki/Diez ).

# %% [markdown]
# (ii) Escribe las ecuaciones del método de Euler para este problema. Escribe una función que las integre.

# %% [markdown]
# Con el método de Euler conocemos:
# $$ x(t + h) = h\cdot f(x,t) + x(t) $$,
# ó
# $$ x(t + h) = h \cdot \dot{x}(t + h) + x(t) $$,
#
# y necesitamos aplicar esto dos veces, para $g(x) = \dot{\theta}$ y $f(x) = \ddot{\theta}$.
#
# $$ \dot{\theta}(t + h) = h\cdot \ddot{\theta}(\dot{\theta},t) + \dot{\theta}(t) $$
# y
# $$ \theta(t + h) = h\cdot \dot{\theta}(\theta,t) + \theta(t) $$

# %%
function euler_pendulo{T<:Number}(f:: Function, x0:: T, v0:: T, t0:: T, tf:: T, h = 1e-3 )
    ts = collect(t0:h:tf)
    #h = abs(ts[1] - ts[2])
    #v_t = h*(f(ts[1])) + v0
    #x_t = h*(v_t) + x0
    xx = [x0]
    vv = [v0]
    for i in 1:length(ts)-1
        v_t = h*(f(ts[i])) + vv[i]
        x_t = h*(v_t) + xx[i]
        push!(xx, x_t)
        push!(vv, v_t)
    end
    return ts, xx, vv
end
# Out:
# WARNING: Method definition euler_pendulo(Function, #T<:Number, #T<:Number, #T<:Number, #T<:Number) in module Main at In[128]:2 overwritten at In[130]:2.
# WARNING: Method definition euler_pendulo(Function, #T<:Number, #T<:Number, #T<:Number, #T<:Number, Any) in module Main at In[128]:2 overwritten at In[130]:2.
# euler_pendulo (generic function with 3 methods)

# %%
euler_pendulo(x-> -a*x, -0.1, 1.0, 0., 1e-2)[2]
# Out:
# 11-element Array{Float64,1}:
#  -0.1
#  -0.099
#  -0.098
#  -0.097
#  -0.096
#  -0.095
#  -0.094
#  -0.0930001
#  -0.0920001
#  -0.0910001
#  -0.0900002

# %%
using Interact, Plots
gr()
# Out:
# Plots.GRBackend()

# %%
a = 1.
plot(euler_pendulo(x-> -a*x, 0.1, 1.0, 0., 1e-2)[1])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 48.3815,384.952 596.063,384.952 596.063,3.93701 48.3815,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="3" width="548" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   103.15,379.237 103.15,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   212.686,379.237 212.686,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   322.222,379.237 322.222,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   431.759,379.237 431.759,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   541.295,379.237 541.295,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,384.952 587.848,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,308.749 587.848,308.749
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,232.546 587.848,232.546
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,156.343 587.848,156.343
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,80.14 587.848,80.14
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,3.93701 587.848,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   103.15,384.952 103.15,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   212.686,384.952 212.686,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   322.222,384.952 322.222,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   431.759,384.952 431.759,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   541.295,384.952 541.295,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 48.3815,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 56.5967,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,308.749 56.5967,308.749
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,232.546 56.5967,232.546
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,156.343 56.5967,156.343
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,80.14 56.5967,80.14
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,3.93701 56.5967,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 103.15, 396.952)" x="103.15" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.686, 396.952)" x="212.686" y="396.952">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 322.222, 396.952)" x="322.222" y="396.952">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 431.759, 396.952)" x="431.759" y="396.952">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 541.295, 396.952)" x="541.295" y="396.952">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 47.1815, 389.452)" x="47.1815" y="389.452">0.000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 47.1815, 313.249)" x="47.1815" y="313.249">0.002</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 47.1815, 237.046)" x="47.1815" y="237.046">0.004</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 47.1815, 160.843)" x="47.1815" y="160.843">0.006</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 47.1815, 84.64)" x="47.1815" y="84.64">0.008</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 47.1815, 8.43701)" x="47.1815" y="8.43701">0.010</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 103.15,346.85 157.918,308.749 212.686,270.647 267.454,232.546 322.222,194.444 376.99,156.343 431.759,118.241 486.527,80.14 541.295,42.0385
#   596.063,3.93701
#   "/>
# <polygon clip-path="url(#clip00)" points="
# 505.547,55.057 578.063,55.057 578.063,24.817 505.547,24.817
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   505.547,55.057 578.063,55.057 578.063,24.817 505.547,24.817 505.547,55.057

# %%
plot(euler_pendulo(x-> -a*x, -0.1, 1.1, 0.0, 6.0)[1], euler_pendulo(x-> -a*x, -0.1, 1.1, 0.0, 6.0)[2])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.6037,379.237 30.6037,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   124.847,379.237 124.847,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   219.09,379.237 219.09,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   313.333,379.237 313.333,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   407.577,379.237 407.577,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   501.82,379.237 501.82,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,379.237 596.063,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,266.228 587.581,266.228
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,141.254 587.581,141.254
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,16.2809 587.581,16.2809
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   124.847,384.952 124.847,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   219.09,384.952 219.09,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   313.333,384.952 313.333,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   407.577,384.952 407.577,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   501.82,384.952 501.82,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,266.228 39.0856,266.228
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,141.254 39.0856,141.254
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,16.2809 39.0856,16.2809
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 30.6037, 396.952)" x="30.6037" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 124.847, 396.952)" x="124.847" y="396.952">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 219.09, 396.952)" x="219.09" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.333, 396.952)" x="313.333" y="396.952">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 407.577, 396.952)" x="407.577" y="396.952">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 501.82, 396.952)" x="501.82" y="396.952">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 396.952)" x="596.063" y="396.952">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 270.728)" x="29.4037" y="270.728">-20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 145.754)" x="29.4037" y="145.754">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 20.7809)" x="29.4037" y="20.7809">0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,17.5306 31.1697,17.448 31.7357,17.3655 32.3018,17.2829 32.8678,17.2004 33.4338,17.1178 33.9998,17.0353 34.5659,16.9528 35.1319,16.8703 35.6979,16.7878
#   36.2639,16.7054 36.83,16.623 37.396,16.5406 37.962,16.4582 38.528,16.3759 39.0941,16.2936 39.6601,16.2114 40.2261,16.1292 40.7921,16.047 41.3582,15.9649
#   41.9242,15.8829 42.4902,15.8009 43.0562,15.719 43.6223,15.6371 44.1883,15.5553 44.7543,15.4735 45.3203,15.3918 45.8864,15.3102 46.4524,15.2287 47.0184,15.1472
#   47.5844,15.0658 48.1505,14.9845 48.7165,14.9033 49.2825,14.8221 49.8485,14.7411 50.4146,14.6601 50.9806,14.5793 51.5466,14.4985 52.1126,14.4179 52.6787,14.3373
#   53.2447,14.2568 53.8107,14.1765 54.3767,14.0963 54.9428,14.0162 55.5088,13.9361 56.0748,13.8563 56.6408,13.7765 57.2069,13.6969 57.7729,13.6174 58.3389,13.538
#   58.9049,13.4587 59.471,13.3796 60.037,13.3006 60.603,13.2218 61.169,13.1431 61.7351,13.0646 62.3011,12.9862 62.8671,12.9079 63.4331,12.8298 63.9992,12.7519
#   64.5652,12.6741 65.1312,12.5965 65.6972,12.5191 66.2633,12.4418 66.8293,12.3647 67.3953,12.2878 67.9613,12.211 68.5274,12.1344 69.093

# %% [markdown]
# (iii) Empezando desde distintas condiciones iniciales, dibuja las trayectorias en el espacio fase $(\theta, \omega)$. ¿Tienen sentido físico?

# %% [markdown]
# (iv) Recuerda que este sistema físico tiene una propiedad especial: existe una **ley de conservación**. ¿Cuál es la cantidad física que se conserva? Escríbela en términos de $\theta$ y $\omega$?

# %% [markdown]
# (v) Dado que se conserva esta cantidad a lo largo de la evolución temporal, desde una condición inicial que tiene un valor dado de esta cantidad conservada, la trayectoria debe mantenerse en una **curva de nivel** de esta cantidad.
#
# Utiliza `contour` para dibujar curvas de nivel, y compáralos gráficamente con las trayectorias que da Euler. ¿Qué observas?

# %% [markdown]
# (vi) Calcula cómo varía la cantidad "conservada" a lo largo de una trayectoria calculada con Euler.

# %% [markdown]
# # El método de Euler-Cromer

# %% [markdown]
# Un cambio aparentemente insignificativo al método numérico puede dar resultados mucho mejores para ciertas clases de sistema.
# En el llamado método de Euler-Cromer, actualizamos
# *primero* la velocidad, y utilizamos esta *nueva* velocidad para actualizar la posición en las reglas usuales del método de Euler.
#
#
# **[2]** (i) Aplica el método de Euler-Cromer al oscilador armónico. Dibuja trayectorias desde varios puntos iniciales en un solo plano fase.

# %% [markdown]
# (ii) Encuentra la tasa de convergencia de Euler-Cromer a la solución exacta cuando tamaño $h$ de un paso converge a cero.

# %% [markdown]
# **[3]** (i) Aplica Euler-Cromer al péndulo simple y dibuja el espacio fase completo. Para hacer esto, escoge distintas condiciones iniciales (posición y velocidad/momento) e integra tanto para adelante como para atrás en el tiempo.
#
# Dibuja el plano fase, así como varias trayectorias como función del tiempo. Describe físicamente lo que observas.

# %% [markdown]
# (ii) Compara trayectorias integradas con las que resultan de usar la cantidad conservada para este sistema.

# %% [markdown]
# # El método de Euler para atrás

# %% [markdown]
# Tomemos otro punto de vista de los métodos numéricos para las EDOs.`
#
# Al integrar los dos lados de la EDO
#
# $$\dot{x}(t) = f(x(t), t)$$
#
# con respecto al tiempo para $t$ entre $t_0$ y $t_0+h$, obtenemos
#
# $$x(t_0+h) - x(t_0) = \int_{t_0}^{t_0+h} f(x(t'), t') dt'.$$
#
# Por lo tanto, podemos intentar aplicar los métodos numéricos que ya vimos para calcular integrales definidas a este problema.

# %% [markdown]
# **[4]** (i) ¿A cuál método de integración numérica corresponde el método de Euler? - es decir, ¿cómo se aproxima la función $f$ adentro de la integral?

# %% [markdown]
# (ii) El siguiente método en complejidad es el llamado método del trapecio, el segundo método que vimos para la integración numérica. Supón (por simplicidad) que $f$ no depende explícitamente de $t$ y aplica el método a la integral para encontrar una ecuación para $x(t_0 + h)$. ¿Qué tipo de ecuación es?

# %% [markdown]
# (iii) ¿Cuál método numérico podemos aplicar para resolver esta ecuación?

# %% [markdown]
# (iv) Implementa esto y pruébalo. Compara los resultados con los del método de Euler.

# %% [markdown]
# (v) ¿Cómo se puede aplicar para sistemas con dos variables?
