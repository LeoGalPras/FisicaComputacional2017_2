# %% [markdown]
# # Ecuaciones diferenciales ordinarias

# %% [markdown]
# Recordemos qué una **ecuación diferencial ordinaria (EDO)** es (aproximadamente) una ecuación en la cual aparece una derivada de una función, y para la cual queremos buscar la solución para esta función.
#
# La EDO más simple no-trivial y físicamente relevante en una variable es
#
# $$\dot{x} = -\alpha x.$$
#
# [Recordemos la notación $\dot{x} := \textstyle \frac{dx}{dt}$, donde $t$ es el tiempo; es muy común en la física que las EDOs involucren derivadas con respecto al tiempo.]

# %% [markdown]
# Una solución a esta ecuación es un objeto $x$, tal que cuando la derivamos con respecto al tiempo, nos da $-\alpha$ (una constante) multiplicada por el mismo objeto. Implícitamente está claro que $x$ depende de $t$, por lo que realmente $x$ se refiere a una función de $t$, es decir $x: \mathbb{R} \to \mathbb{R}$, con $x: t \mapsto x(t)$. Esta ecuación se puede considerar como ecuación *funcional*, es decir, una igualdad de funciones.
#
# Esta ecuación se puede escribir más explícitamente como sigue:
#
# $$\dot{x}(t) = -\alpha x(t) \qquad \text{para cada } t \in \mathbb{R}.$$
#
# En mi opinión, en esta forma queda más claro.
#
# Esto quiere decir que si *de alguna manera* hayamos logrado saber que la solución en el tiempo $t$ está en la posición $x(t)$, entonces nos indica cuál será la *velocidad* $\dot{x}(t)$ en este momento.

# %% [markdown]
# La forma general de una EDO en una variable es
#
# $$\dot{x} = f(x, t),$$
#
# o sea
#
# $$\dot{x}(t) = f(x(t), t) \qquad \text{para cada } t \in \mathbb{R}.$$
#
# Recordemos que debe ir acompañada por una condición inicial $x(t=t_0) = x_0$ para que constituya un problema bien posado (*problema de valores iniciales*, o *problema de Cauchy*).
# La solución de una ecuación de este tipo será una *función* $x(t)$ que satisface al mismo tiempo que $\dot{x}(t) = f(x(t), t)$ para cada $t$, y que $x(t=t_0) = x_0$.
#
# En el caso particular de la ecuación $\dot{x} = -\alpha x$, conocemos analíticamente la solución, y nos servirá para comprobar nuestros métodos. Pero para las ecuaciones de interés para la física, esto *casi nunca ocurre*, una situación que ¡suele pasar desapercibida durante la carrera! En estos casos, debemos aplicar distintas técnicas de *aproximación* de la solución, entre las cuales se destacan los *métodos numéricos*.

# %% [markdown]
# # Método de Euler

# %% [markdown]
# Para resolver una EDO numéricamente en la computadora, tendremos que *aproximar* la solución continua $x: t \mapsto x(t)$ con una versión con una cantidad finita de información, es decir, *discretizarla* de alguna forma.
#
# La manera más sencilla de hacerla es usando *diferencias finitas*.

# %% [markdown]
# **[1]** (i) ¿Cuál es la aproximación más sencilla de la derivada $\dot{x}(t)$, en términos de un tamaño de paso pequeño $h$?

# %% [markdown]
# Sería utilizar
# $$ \dot{x}(t_0 + h) \approx \frac{x(t_0 + h) - x(t_0)}{h}  $$,
# con h pequeña.

# %% [markdown]
# (ii) Aplica esta aproximación con la ecuación $\dot{x} = f(x, t)$ para obtener una expresión para $x(t+h)$, es decir el valor *predicho* en el siguiente *paso* de tiempo, en términos del valor ya conocido $x(t)$.

# %% [markdown]
# Entonces utilizando esta $f$ tendríamos que
# $$ x(t + h) = h\cdot f(x,t) + x(t) $$,
# entonces tendríamos
# $$ x(t + h) = h \cdot \dot{x}(t + h) + x(t) $$

# %% [markdown]
# (iii) Implementa este *método de Euler* en una función. Para hacerlo, crea un arreglo `ts` de los tiempos en los cuales se evaluará la función. Luego crea otro arreglo de ceros, con la función `zeros`. [Si pasas el arreglo `t` como argumento a esta función, creará un arreglo del mismo tamaño automáticamente.] Ahora implementa el paso (ii) en un algoritmo iterativo para actualizar los valores en el nuevo arreglo para cada tiempo sucesivamente.

# %%
function euler(f:: Function, x0:: Number, t0:: Number, tf:: Number, h = 1e-3)
    ts = t0:h:tf
    xx = zeros(ts)
    xx[1] = x0
    for  i in 1:length(ts)-1
        #@show f(xx[i],ts[i]), xx[i]
        xx[i+1] = h * f(xx[i],ts[i]) + xx[i]
    end
    return ts,xx
end
# Out:
# WARNING: Method definition euler(Function, Number, Number, Number) in module Main at In[100]:2 overwritten at In[235]:2.
# WARNING: Method definition euler(Function, Number, Number, Number, Any) in module Main at In[100]:2 overwritten at In[235]:2.
# euler (generic function with 2 methods)

# %%
euler((x,t) -> x,1,0,1,1e-2)[2]
# Out:
# 101-element Array{Float64,1}:
#  1.0
#  1.01
#  1.0201
#  1.0303
#  1.0406
#  1.05101
#  1.06152
#  1.07214
#  1.08286
#  1.09369
#  1.10462
#  1.11567
#  1.12683
#  ⋮
#  2.42439
#  2.44863
#  2.47312
#  2.49785
#  2.52283
#  2.54806
#  2.57354
#  2.59927
#  2.62527
#  2.65152
#  2.67803
#  2.70481

# %%
euler(t -> 2t,1.,0,1,11)[2];

# %%
using Plots, Interact
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# (iv) Verifica que funcione tu método al aplicarlo a una función $f(t)$ sencilla que dependa *únicamente del tiempo*. [Recuerda que debes imponer una condición inicial.] ¿Cuál operación matemática acabas de llevar a cabo? Compara con la solución analítica.

# %%
algo, algo2 = euler((x,t)->cos(t), 2., 0, 2pi, 1e-1)
scatter(algo, algo2 ,
    label="x(t) aprox.",
    ylabel="x(t)", xlabel="t",
    title="Solución de la ODE con Euler",
    alpha=.1)
plot!(0:0.1:2pi,t -> sin(t) + 2, label = "sin(t) + 2", linewidth=2, c=:green, linestyle=:dash)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 28.1037,369.674 596.063,369.674 596.063,23.3815 28.1037,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="23" width="568" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   44.178,364.48 44.178,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   260.231,364.48 260.231,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   476.283,364.48 476.283,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   36.6231,359.886 587.544,359.886
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   36.6231,200.534 587.544,200.534
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   36.6231,41.1817 587.544,41.1817
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   44.178,369.674 44.178,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   260.231,369.674 260.231,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   476.283,369.674 476.283,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,369.674 28.1037,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,359.886 36.6231,359.886
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,200.534 36.6231,200.534
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,41.1817 36.6231,41.1817
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 44.178, 381.674)" x="44.178" y="381.674">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.231, 381.674)" x="260.231" y="381.674">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 476.283, 381.674)" x="476.283" y="381.674">5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.9037,
#   226.889,315.107 229.729,314.019 232.569,312.92 235.409,311.811 238.249,310.69 241.088,309.558 243.928,308.415 246.768,307.261 249.608,306.094 252.448,304.917
#   255.287,303.727 258.127,302.526 260.967,301.312 263.807,300.086 266.647,298.849 269.486,297.598 272.326,296.336 275.166,295.06 278.006,293.772 280.846,292.471
#   283.685,291.157 286.525,289.83 289.365,288.489 292.205,287.135 295.0

# %% [markdown]
# **[2]** (i) Utiliza tu función para resolver la ecuación $\dot{x} = -\alpha x$, con  y compara tu solución numérica gráficamente con la solución analítica de la ecuación. ¿Qué pasa al variar el paso de tiempo? Hazlo interactivo.

# %% [markdown]
# Utilizando la función dada al inicio del notebook, su integral definida es
# $$ x(t) = Ce^{-\alpha t}$$, con $\alpha = 10$, $t0 = 0$ y $x_0 = x(t_0) = 2$, queda
# $$ x(t) = 2 e^{-10 t}$$

# %%
EE,FF = euler((x,t)-> -10x, 2. , 0, 10, 1e-1)
plot(EE,FF,
    label="x(t) aprox.",
    ylabel="x(t)", xlabel="t",
    title="Solución de la ODE con Euler",
    alpha=.8,
    ylims=(-0.1, 2.1),
    xlims=(0,1)
    )
plot!(0:0.01:10, t-> 2exp(-10t), label = "sol. analítica", linewidth=2, c=:red, linestyle=:dash)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 28.1037,369.674 596.063,369.674 596.063,23.3815 28.1037,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="23" width="568" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   28.1037,364.48 28.1037,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   141.696,364.48 141.696,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   255.287,364.48 255.287,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   368.879,364.48 368.879,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   482.471,364.48 482.471,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,364.48 596.063,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   36.6231,353.934 587.544,353.934
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   36.6231,196.528 587.544,196.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   36.6231,39.122 587.544,39.122
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,369.674 28.1037,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   141.696,369.674 141.696,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255.287,369.674 255.287,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   368.879,369.674 368.879,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   482.471,369.674 482.471,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,369.674 596.063,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,369.674 28.1037,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,353.934 36.6231,353.934
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,196.528 36.6231,196.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,39.122 36.6231,39.122
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 28.1037, 381.674)" x="28.1037" y="381.674">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 141.696, 381.674)" x="141.696" y="381.674">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 255.287, 381.674)" x="255.287" y="381.674">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 368.879, 381.674)" x="368.879" y="381.674">0.6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 482.471, 381.674)" x="482.471" y="381.674">0.8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 381.674)" x="596.063" y="381.674">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.9037, 358.434)" x="26.9037" y="358.434">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.9037, 201.028)" x="26.9037" y="201.028">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.9037, 43.622)" x="26.9037" y="43.622">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 312.083, 18)" x="312.083" y="18">Solución de la ODE con Euler</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 312.083, 397.6)" x="312.083" y="397.6">t</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">x(t)</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:0.8; fill:none" points="
#   28.1037,39.122 84.8996,353.934 141.696,353.934 198.491,353.934 255.287,353.934 312.083,353.934 368.879,353.934 425.675,353.934 482.471,353.934 539.267,353.934
#   596.063,353.934 652.859,353.934 709.655,353.934 766.451,353.934 823.247,353.934 880.043,353.934 936.839,353.934 993.635,353.934 1050.43,353.934 1107.23,353.934
#   1164.02,353.934 1220.82,353.934 1277.61,353.934 1334.41,353.934 1391.21,353.934 1448,353.934 1504.8,353.934 1561.59,353.934 1618.39,353.934 1675.19,353.934
#   1731.98,353.934 1788.78,353.934 1845.57,353.934 1902.37,353.934 1959.17,353.934 2015.96,353.934 2072.76,353.934 2129.55,353.934 2186.35,353.934 2243.15,353.934
#   2299.94,353.934 2356.74,353.934 2413.53,353.934 2470.33,353.934 2527.12,353.934 2583.92,353.934 2640.72,353.934 2697.51,353.934 2754.31,353.934 2811.1,353.934
#   2867.9,353.934 2924.7,353.934 2981.49,353.934 3038.29,353.934 3095.08,353.934 3151.88,353.934 3208.68,353.934 3265.47,353.934 3

# %% [markdown]
# (ii) Dado que el método de Euler utiliza una aproximación, el resultado no es exacto. Fija una $t$ final y calcula el error (desde la solución analítica) en función del tamaño de paso $h$. ¿Cómo es la convergencia en función de $h$?

# %%
#function error_euler(h_min = 0,h_max = -6, n = 10)
    HH = logspace(0, -6, 10)
    errores = zeros(HH)
    for h in HH, i in 1:length(HH)
        errores[i] = abs(euler((x,t)-> -10x, 2., 0, 1, h)[2][end] - 2exp(-10))
        #scatter!(HH, error)
        #display()
    end
    p = scatter(HH,errores, yscale=:log10, xscale=:log10)
#end

#error_euler()
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 48.3815,384.952 596.063,384.952 596.063,3.93701 48.3815,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="3" width="548" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   48.3815,379.237 48.3815,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   139.662,379.237 139.662,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   230.942,379.237 230.942,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   322.222,379.237 322.222,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   413.502,379.237 413.502,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   504.783,379.237 504.783,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,379.237 596.063,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,232.282 587.848,232.282
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   56.5967,3.93701 587.848,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 48.3815,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   139.662,384.952 139.662,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   230.942,384.952 230.942,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   322.222,384.952 322.222,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   413.502,384.952 413.502,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   504.783,384.952 504.783,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,384.952 48.3815,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,232.282 56.5967,232.282
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   48.3815,3.93701 56.5967,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 36.3029, 401.904)" x="36.3029" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 49.4822, 395.051)" x="49.4822" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.1059, 395.051)" x="55.1059" y="395.051">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 127.583, 401.904)" x="127.583" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 140.762, 395.051)" x="140.762" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 146.386, 395.051)" x="146.386" y="395.051">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 218.863, 401.904)" x="218.863" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 232.043, 395.051)" x="232.043" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 237.666, 395.051)" x="237.666" y="395.051">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 310.144, 401.904)" x="310.144" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 323.323, 395.051)" x="323.323" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 328.947, 395.051)" x="328.947" y="395.051">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 401.424, 401.904)" x="401.424" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 414.603, 395.051)" x="414.603" y="395.051">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 420.227, 395.051)" x="420.227" y="395.051">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 492.704, 401.904)" x="492.704" y="401.904">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Ne

# %%
euler((x,t)-> -10x, 2., 0, 1, 1e-2)[2][end]
# Out:
# 5.312279777517495e-5

# %%
?logspace
# Out:
# search: logspace
# ```
# logspace(start, stop, n=50)
# ```
#
# Construct a vector of `n` logarithmically spaced numbers from `10^start` to `10^stop`.

# %%
logspace(-1,-6,10)
# Out:
# 10-element Array{Float64,1}:
#  0.1
#  0.0278256
#  0.00774264
#  0.00215443
#  0.000599484
#  0.00016681
#  4.64159e-5
#  1.29155e-5
#  3.59381e-6
#  1.0e-6

# %%
.000001
# Out:
# 1.0e-6

# %% [markdown]
# **[3]** Considera la ecuación diferencial nolineal $\dot{x} = x*(1-x)$ que modela la dinámica de una población. Resúelvela numéricamente desde distintas condiciones iniciales y dibuja las soluciones correspondientes. Interpreta el resultado.

# %% [markdown]
# # Varias variables

# %% [markdown]
# El método de Euler se extiende directamente a EDOs con más de una variable.

# %% [markdown]
# **[4]** (i) Deriva un método de Euler para las ecuaciones acopladas
# $$\dot{x} = f(x, y);$$
# $$\dot{y} = g(x, y).$$
#
# Para hacerlo, aplica la definición de la derivada de nuevo.
#
# (ii) Implementa el método.
#
# (iii) Aplícalo a la ecuación diferencial lineal que describe un oscilador armónico amortiguado. [Pista: Recuerda que para hacerlo, hay un "truco" para reducir una ecuación diferencial de segundo orden a dos ecuaciones de primer orden; ¿cuál es?
#
# (iv) Calcula trayectorias desde distintas condiciones iniciales y dibújalas, y/o ¡hazlo interactivo!
# Debes dibujar tanto $x(t)$ y $y(t)$ como funciones del tiempo, como el **espacio fase**.

# %% [markdown]
# ## El enfoque vectorial

# %% [markdown]
# Recordemos que *cualquier* EDO, *incluídas las de orden superior* (es decir, con derivadas más altas que la primera de alguna función) se puede escribir en la forma
# $$\dot{\mathbf{x}} = \mathbf{f}(\mathbf{x}, t) \qquad (*)$$
#
# es decir
#
# $$\dot{\mathbf{x}}(t) = \mathbf{f}(\mathbf{x}(t), t),$$
#
# donde ahora $\mathbf{x} = (x_1, \ldots, x_n) \in \mathbb{R}^n$ es un vector y $\mathbf{f}: \mathbb{R}^n \to \mathbb{R}^n$ es una función vectorial, que nos da un **campo vectorial** que indica en cuál dirección seguir desde cada punto del espacio.

# %% [markdown]
# **[5]** (i) Escribe una función para hacer un paso del método de Euler para las ecuaciones acopladas
#
# $$\dot{\mathbf{x}} = \mathbf{f}(\mathbf{x}, t).$$
#
# El código ahora deberá ser *genérico*, es decir, debe funcionar para cualquier función $\mathbf{f}$ y vector $\mathbf{x}$.
#
# (ii) Escribe el método de Euler completo.
#
# (iii) Úsalo para resolver la caída libre y una caída con fricción lineal en la velocidad. Compara con el resultado exacto. Dibuja las resultados con distintos tamaños de fricción.
#
# (iv) Resuelve la caída libre con fricción cuadrática en la velocidad.

# %% [markdown]
# **[6]** (i) Resuelve numéricamente el problema del tiro parabólico con Euler para un proyectil que empieza en una altura $h>0$ con rapidez $1$ y ángulo inicial $\alpha$, *hasta que* caiga al suelo.
#
# (ii) Encuentra la distancia horizontal donde cae al suelo (el rango). Dibuja el resultado tal que puedas manipular interactivamente las condiciones iniciales. Encuentra numéricamente el ángulo que maximiza el rango. ¿Es correcto?
#
# (iii) Agrega fricción del aire al problema y agrégalo como otro parámetro que puedas manipular. ¿Cómo cambia el resultado de la pregunta (ii)?
