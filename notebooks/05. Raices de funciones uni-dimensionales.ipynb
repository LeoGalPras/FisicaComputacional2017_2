# %% [markdown]
# # Raíces de funciones uni-dimensionales

# %% [markdown]
# En este notebook, investigaremos algunos métodos para encontrar **raíces** de funciones uni-dimensionales, usando métodos iterativos. Esto es un problema que ocurre por todos lados en la física, por ejemplo para el pozo cuadrado en mecánica cuántica, o para encontrar el valor máximo de una función.
#
# Recuerda que $x^*$ es una raíz (o cero) de la función $f$ si $f(x^*) = 0$. Como sabemos, en general las raíces de una función no se pueden encontrar de manera analítica, excepto para funciones $f$ que sean polinomios de grado $\le 4$.
#
# Por lo tanto, para encontrar raíces tendremos que utilizar algoritmos iterativos.
# Recuerda que un algoritmo iterativo tiene la forma general
#
# $$x_{n+1} := f(x_n),$$
#
# y consiste en comenzar en un punto inicial $x_0$ y generar una secuencia $x_1 = f(x_0)$; $x_2 = f(x_1)$, etc.
# Si diseñamos correctamente el algoritmo, la esperanza es que la secuencia $(x_n)_{n=1}^\infty$ converja a alguna raíz  $x^*$ con $f(x_\infty) = 0$, es decir que $f(x_n) \to 0$ cuando $n \to \infty$.

# %% [markdown]
# Dado que no podemos llevar a cabo la iteración un número infinito de veces, se corta la iteración después de un cierto número de pasos, para dar una solución *aproximada*, que se encuentra dentro de cierta *tolerancia* del resultado teórico exacto $x^*$. Por lo tanto, cualquier algoritmo iterativo requiere una condición de terminación.

# %% [markdown]
# # Raíces de funciones: Bisección

# %% [markdown]
# Un primer método para encontrar una raíz es el **método de bisección**.
# Dada una función continua $f$, una condición suficiente (pero no necesaria) para que *exista* una raiz en un intervalo dado $[a, b]$ es que $F$ cambie de signo en el intervalo, es decir, que $f(a)$ y $f(b)$ tengan signos opuestos. Si ocurre esto, entonces el teorema del valor intermedio nos dice que se sigue que $f$ sí tiene al menos una raíz en $[a, b]$.

# %% [markdown]
# [1] La idea del método de bisección es de adivinar que el punto medio del intervalo $[a, b]$ sea una primera aproximación para la raíz. Escribamos una función que implemente bisección, que toma como argumento la función $f$ y el intervalo $[a, b]$.
#
# (i) Define $c$ como el punto medio del intervalo.
#
# (ii) Esto divide el intervalo original en dos partes. Es posible (aunque improbable) que $c$ ya es la raíz, en cuyo caso ya podemos terminar la función y regresar la raíz que hemos encontrado. ¿Cómo se checa si ya es la raíz? Si no, ¿cómo podemos saber en cuál de los dos sub-intervalos cae la raíz? Impleméntalo.
#
# [Pista: Tal vez querrás definir una función `signo` que toma un argumento `x` y regresa $0$ si `x` es igual a `0`, regresa `1` si `x` es mayor que cero, y regresa `-1` si `x` es menor que cero.]
#
# (iii) Repite estos pasos hasta que encuentres la raíz con cierta tolerancia.

# %%
function signo(x::Real)
   if x < 0
        return signo_x = -1
    elseif x == 0
        return signo_x = 0
    elseif x > 0
        return signo_x = 1
    end
end



"""
Función que calcula una raíz 'raiz' de una función real F en un intervalo [a,b] utilizando el método de bisección.
"""
function ceros_biseccion(F::Function, a::Real, b::Real)
    c = (a+b)/2      #calculo el punto medio
    if signo(F(c)) == 0
        return raiz = c #si le atinas justo a la mitad del intervalo regresa
    else
        i = 0 #inicio contador para tolerancia
        while abs(F(c)) > 1e-15 #defino una tolerancia de la raiz menor a 10^-15
            i += 1
            if signo(F(c))*signo(F(a)) < 0
                a, b = a, c #a se queda igual, b se vuelve el punto medio [a,b]->[a,c]
                c = (a+b)/2
                if i == 100000
                    error("No se encontró raíz.")
                end
            else
                a, b = c, b #b se queda igual, a se vuelve el punto medio [a,b]->[c,b]
                c = (a+b)/2
                if i == 100000
                    error("No se encontró raíz.")
                end
            end
        end
        end      
    return raiz = c
end
# Out:
# WARNING: Method definition signo(Real) in module Main at In[12]:2 overwritten at In[17]:2.
# WARNING: Method definition ceros_biseccion(Function, Real, Real) in module Main at In[12]:17 overwritten at In[17]:17.
# WARNING: replacing docs for 'ceros_biseccion :: Tuple{Function,Real,Real}' in module 'Main'.
# ceros_biseccion

# %%
g(x) = x^2 -2
ceros_biseccion(g, 1, 3)
# Out:
# WARNING: Method definition g(Any) in module Main at In[21]:1 overwritten at In[68]:1.
# 1.414213562373095

# %%
pi/2
# Out:
# 1.5707963267948966

# %%
ceros_biseccion(cos, 1, 3)
# Out:
# 1.5707963267948966

# %% [markdown]
# [2] Aplica tu función para encontrar *las dos* raíces cuadradas de $2$. Para hacerlo, tendrás que escoger (a mano) intervalos iniciales a mano cumplan con la condición de cambio de signo.

# %%
h(x) = x - sqrt(2)
ceros_biseccion(h,-0.1,3)
# Out:
# WARNING: Method definition h(Any) in module Main at In[24]:1 overwritten at In[71]:1.
# 1.4142135623730958

# %%
ceros_biseccion(g,-2,-1)
# Out:
# -1.414213562373095

# %% [markdown]
# [3] (i) Haz una versión nueva de tu función que regresa un arreglo de todos los iterados `x`. Utiliza un método gráfico para estimar la tasa de convergencia del método hacia la raíz.

# %%
function ceros_biseccion2(F::Function, a::Real, b::Real)
    iterados_x = Float64[]
    c = (a+b)/2      #calculo el punto medio
    push!(iterados_x,F(c))
    if signo(F(c)) == 0
        return raiz = c #si le atinas justo a la mitad del intervalo regresa
    else
        i = 0 #inicio contador para tolerancia
        while abs(F(c)) > 1e-15 #defino una tolerancia de la raiz menor a 10^-15
            i += 1
            if signo(F(c))*signo(F(a)) < 0
                a, b = a, c #a se queda igual, b se vuelve el punto medio [a,b]->[a,c]
                c = (a+b)/2
                if i == 100000
                    error("No se encontró raíz.")
                end
            else
                a, b = c, b #b se queda igual, a se vuelve el punto medio [a,b]->[c,b]
                c = (a+b)/2
                if i == 100000
                    error("No se encontró raíz.")
                end
            end
            push!(iterados_x,F(c))
        end
        end      
    return iterados_x, c
end
# Out:
# WARNING: Method definition ceros_biseccion2(Function, Real, Real) in module Main at In[73]:2 overwritten at In[84]:2.
# ceros_biseccion2 (generic function with 1 method)

# %%
using Plots
gr();

# %%
iterados = ceros_biseccion2(cos, -2,0)[1]
scatter(abs(iterados), yscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 57.2703,384.952 596.063,384.952 596.063,3.93701 57.2703,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="57" y="3" width="539" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.1458,379.237 62.1458,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   269.613,379.237 269.613,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   477.08,379.237 477.08,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,355.967 587.981,355.967
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,236.494 587.981,236.494
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,117.021 587.981,117.021
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   62.1458,384.952 62.1458,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   269.613,384.952 269.613,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   477.08,384.952 477.08,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 57.2703,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,355.967 65.3522,355.967
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,236.494 65.3522,236.494
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,117.021 65.3522,117.021
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 62.1458, 396.952)" x="62.1458" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.613, 396.952)" x="269.613" y="396.952">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 477.08, 396.952)" x="477.08" y="396.952">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 26.5592, 361.899)" x="26.5592" y="361.899">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 39.7385, 355.047)" x="39.7385" y="355.047">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.3622, 355.047)" x="45.3622" y="355.047">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 26.5592, 242.426)" x="26.5592" y="242.426">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 39.7385, 235.574)" x="39.7385" y="235.574">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.3622, 235.574)" x="45.3622" y="235.574">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 31.9133, 122.953)" x="31.9133" y="122.953">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.0926, 116.101)" x="45.0926" y="116.101">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 50.7163, 116.101)" x="50.7163" y="116.101">5</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="82.8926" cy="25.0357" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="82.8926" cy="25.0357" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="93.2659" cy="15.445" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="93.2659" cy="15.445" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="103.639" cy="27.8034" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="103.639" cy="27.8034" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="114.013" cy="47.276" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="114.013" cy="47.276" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="124.386" cy="36.7161" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="124.386" cy="36.7161" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="134.759" cy="48.5629" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="134.759" cy="48.5629" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="145.133" cy="76.7664" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="145.133" cy="76.7664" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="155.506" cy="56.4646" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="155.506" cy="56.4646" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="165.879" cy="65.2392" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1"

# %% [markdown]
# (ii) Haz una versión nueva de tu función que escoge otro punto (que no sea el punto medio) entre $a$ y $b$, escogido de forma lineal entre $a$ y $b$ con un parámetro $\alpha$, tal que $\alpha = 0$ da $a$ y $\alpha=1$ da $b$. ¿Cambia la tasa de convergencia?

# %%
function ceros_biseccion3(F::Function, a::Real, b::Real, α::Float64 = 0.5)
    if α < 0.0 || α > 1.0
        error("α debe de ser un valor entre 0.0 y 1.0 .")
    end
    iterados_x = Float64[]
    c = a + (b-a)*α     #calculo el punto medio
    push!(iterados_x,F(c))
    if signo(F(c)) == 0
        return raiz = c #si le atinas justo a la mitad del intervalo regresa
    else
        i = 0 #inicio contador para tolerancia
        while abs(F(c)) > 1e-15 #defino una tolerancia de la raiz menor a 10^-15
            i += 1
            if signo(F(c))*signo(F(a)) < 0
                a, b = a, c #a se queda igual, b se vuelve el punto medio [a,b]->[a,c]
                c = a + (b-a)*α
                if i == 100000
                    error("No se encontró raíz.")
                end
            else
                a, b = c, b #b se queda igual, a se vuelve el punto medio [a,b]->[c,b]
                c = a + (b-a)*α
                if i == 100000
                    error("No se encontró raíz.")
                end
            end
            push!(iterados_x,F(c))
        end
        end      
    return iterados_x, c
end
# Out:
# WARNING: Method definition ceros_biseccion3(Function, Real, Real) in module Main at In[94]:2 overwritten at In[128]:2.
# WARNING: Method definition ceros_biseccion3(Function, Real, Real, Float64) in module Main at In[94]:2 overwritten at In[128]:2.
# ceros_biseccion3 (generic function with 3 methods)

# %%
its_alpha02 = ceros_biseccion3(cos, 1, 2, .2)[1]
its_alpha08 = ceros_biseccion3(cos, 1, 2, .8)[1]
scatter(abs(its_alpha02), label="alpha= 0.2", yscale=:log10)
scatter!(abs(its_alpha08), label="alpha= 0.8", yscale=:log10)
scatter!(abs(iterados), label="alpha= 0.5", yscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 57.2703,384.952 596.063,384.952 596.063,3.93701 57.2703,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="57" y="3" width="539" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   64.3209,379.237 64.3209,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   269.279,379.237 269.279,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   474.236,379.237 474.236,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,355.967 587.981,355.967
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,236.494 587.981,236.494
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,117.021 587.981,117.021
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   64.3209,384.952 64.3209,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   269.279,384.952 269.279,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   474.236,384.952 474.236,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 57.2703,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,355.967 65.3522,355.967
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,236.494 65.3522,236.494
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,117.021 65.3522,117.021
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 64.3209, 396.952)" x="64.3209" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.279, 396.952)" x="269.279" y="396.952">25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 474.236, 396.952)" x="474.236" y="396.952">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 26.5592, 361.899)" x="26.5592" y="361.899">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 39.7385, 355.047)" x="39.7385" y="355.047">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.3622, 355.047)" x="45.3622" y="355.047">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 26.5592, 242.426)" x="26.5592" y="242.426">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 39.7385, 235.574)" x="39.7385" y="235.574">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.3622, 235.574)" x="45.3622" y="235.574">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 31.9133, 122.953)" x="31.9133" y="122.953">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.0926, 116.101)" x="45.0926" y="116.101">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 50.7163, 116.101)" x="50.7163" y="116.101">5</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="72.5192" cy="8.0827" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="72.5192" cy="8.0827" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="80.7175" cy="13.7815" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="80.7175" cy="13.7815" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="88.9158" cy="23.414" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="88.9158" cy="23.414" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="97.1141" cy="38.353" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="97.1141" cy="38.353" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="105.312" cy="26.3577" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="105.312" cy="26.3577" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="113.511" cy="29.5203" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="113.511" cy="29.5203" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="121.709" cy="33.005" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="121.709" cy="33.005" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="129.907" cy="36.9976" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="129.907" cy="36.9976" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="138.106" cy="41.8829" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1

# %%
raiz3(x) = x^2 - 3
r_alpha02 = ceros_biseccion3(raiz3, 1, 2, .2)[1]
r_alpha08 = ceros_biseccion3(raiz3, 1, 2, .8)[1]
r_alpha05 = ceros_biseccion3(raiz3, 1, 2, .5)[1]
scatter(abs(r_alpha02), label="alpha= 0.2", ylabel="F_n", xlabel="n", yscale=:log10, xscale=:log10)
scatter!(abs(r_alpha08), label="alpha= 0.8", yscale=:log10, xscale=:log10)
scatter!(abs(r_alpha05), label="alpha= 0.5", yscale=:log10, xscale=:log10)
# Out:
# WARNING: Method definition raiz3(Any) in module Main at In[150]:1 overwritten at In[151]:1.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 72.5481,369.674 596.063,369.674 596.063,3.93701 72.5481,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="72" y="3" width="524" height="366"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   72.5481,364.188 72.5481,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   212.148,364.188 212.148,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   351.747,364.188 351.747,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   491.346,364.188 491.346,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,361.38 588.21,361.38
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,243.747 588.21,243.747
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,126.114 588.21,126.114
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,8.48058 588.21,8.48058
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   212.148,369.674 212.148,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   351.747,369.674 351.747,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   491.346,369.674 491.346,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,361.38 80.4008,361.38
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,243.747 80.4008,243.747
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,126.114 80.4008,126.114
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,8.48058 80.4008,8.48058
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 59.2659, 386.626)" x="59.2659" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 72.4452, 379.773)" x="72.4452" y="379.773">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 198.865, 386.626)" x="198.865" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 212.045, 379.773)" x="212.045" y="379.773">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 338.465, 386.626)" x="338.465" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 351.644, 379.773)" x="351.644" y="379.773">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 478.064, 386.626)" x="478.064" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 491.243, 379.773)" x="491.243" y="379.773">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 367.312)" x="41.837" y="367.312">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 360.46)" x="55.0163" y="360.46">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 360.46)" x="60.64" y="360.46">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 249.679)" x="41.837" y="249.679">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 242.826)" x="55.0163" y="242.826">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 242.826)" x="60.64" y="242.826">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 132.046)" x="47.1911" y="132.046">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 125.193)" x="60.3703" y="125.193">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 125.193)" x="65.994" y="125.193">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 52.8148, 14.4125)" x="52.8148" y

# %% [markdown]
# Probamos la convergencia para una $\alpha$ encima de 0.5 y para una debajo de 0.5, en la primera gráifca no es muy claro si converge más rápidamente $\alpha = 0.5$ ó $\alpha = 0.2$, por eso probamos con otra función, en la que la raíz esté más lejos de 1.2, y vemos que por lo general funciona mejor para $\alpha = 0.5$ .

# %% [markdown]
# # Raíz cuadrada: El algoritmo Babilónico

# %% [markdown]
# Un ejemplo de un algoritmo sorprendente es el *algoritmo Babilónico* (o de Herón) para calcular la raiz cuadrada $\sqrt{y}$ de un número real $y$.

# %% [markdown]
# [4] ¿De cuál ecuación es raíz el número $\sqrt{y}$? ¿Cuál otra solución de esta ecuación hay?

# %% [markdown]
# $$ f(x) = x^2 - y $$

# %% [markdown]
# Para un algoritmo, siempre necesitamos una *idea*, que toma una adivinanza $x_n$ y produce una (probablemente) mejor, $x_{n+1}$. La idea del algoritmo Babilónico es la siguiente.

# %% [markdown]
# [5] (i) Dada una adivinanza $x_n$, es posible (pero improbable) que $x_n$ ya es $\sqrt{y}$. ¿Cómo lo puedes verificar, sin utilizar (por supuesto) alguna función en Julia que calcule la raíz cuadrada? Escribe el código correspondiente.

# %% [markdown]
# (ii) Si $x_n$ no es raíz, demuestra que $\frac{y}{x_n}$ se encuentra *del lado opuesto de $\sqrt{y}$ que $x_n$* sobre la recta real.

# %% [markdown]
# (iii) Así, tenemos dos valores que se encuentran por dos lados diferentes de $\sqrt{y}$. ¿Cuál sería una mejor adivinanza para $x_{n+1}$? Impleméntalo.

# %% [markdown]
# [6] (i) Utiliza esta idea para escribir una función que calcule $\sqrt{y}$ para una $y$ dada.

# %% [markdown]
# (ii) ¿Qué tan rápido converge a la raíz cuadrada? Grafícalo.

# %%
# Out:
# search:
#
# Couldn't find derivative
# Perhaps you meant serialize
# No documentation found.
#
# Binding `derivative` does not exist.
