# %% [markdown]
# # Optimización

# %% [markdown]
# Una tarea importante es la **optimización**, es decir, encontrar máximos y mínimos de funciones. Representa una aplicación de suma importancia de derivadas, como aprendimos en Cálculo 1 y 3.
#
# [1] Escribe una función que toma una función $f:\mathbb{R} \to \mathbb{R}$ lisa (es decir, suficientemente diferenciable), y utiliza el método de Newton para encontrar:
# (i) los valores de $x$ en los cuales la función toma su valor máximo y mínimo;
# (ii) el valor ahí;
# (iii) si es un máximo o un mínimo.
#
# [Pista: ¿Cuáles son las condiciones matemáticas que se deben cumplir para (i) y (iii)?]

# %% [markdown]
# Para saber esto, como hemos visto en todos los cursos de la carrera, podemos utilizar la primera derivada e igualarla a cero para saber si es un valor extremo local de la función (o un punto de inflexión) $f'(x_0) = 0$, y para saber qué tipo de extremo utilizamos la segunda derivada y vemos su signo si: $f''(x_0) > 0$ ent. $x_0$ es un mínimo, $f''(x_0) < 0 $ ent. $x_0$ es un máximo, $f''(x_0) = 0$ ent. $x_0$ es un punto de inflexión.

# %%
function df(f:: Function, x0:: Number, h:: Real = 1e-10)
   df = (f(x0 + h) - f(x0 - h) )/ 2h #centrada
    return df
end

function d2f(f:: Function, x0:: Number, h:: Real = 1e-10) #segunda derivada centrada
    d2f = (f(big(x0 + h)) + f(big(x0 - h)) - 2f(big(x0))) /(h^2) #da -Inf sin big
   return d2f
end

function valores_extremos(f, x0) #newton para la primera derivada
    i = 0
    while abs(df(f,x0)) > 1e-15
        i += 1
        x0 -= df(f,x0)/d2f(f,x0)
        if i == 1000
            error("Número límite de iteraciones")
        end
    end
    
    if d2f(f,x0) < 0 && abs(d2f(f,x0)) > 1e-15 #ver que no sea demasiado cercano a cero
        return "máximo en $(convert(Float64,x0)), f(x0) = $(convert(Float64,f(x0)))"
    elseif d2f(f,x0) > 0 && abs(d2f(f,x0)) > 1e-15
        return "mínimo en $(convert(Float64,x0)), f(x0) = $(convert(Float64,f(x0)))"
    elseif abs(d2f(f,x0)) < 1e-15 || abs(d2f(f,x0)) == 0
        return "punto de inflexión en $(convert(Float64,x0)), f(x0) = $(convert(Float64,f(x0)))"
    end
end
# Out:
# valores_extremos (generic function with 1 method)

# %%
valores_extremos(x -> x^3  + 1, 0.)
# Out:
# "punto de inflexión en 0.0, f(x0) = 1.0"

# %%
valores_extremos(x -> x^3  + 1, 1.)
# Out:
# "mínimo en 1.490108786130225e-8, f(x0) = 1.0"

# %%
valores_extremos(x -> x^3  + 1, -1.)
# Out:
# "máximo en -1.490108786130225e-8, f(x0) = 1.0"

# %% [markdown]
# [2] Otro método para optimizar es darse cuenta de que la función misma te puede dar información sobre por dónde buscar.
#
# (i) Considerando una función $f:\mathbb{R} \to \mathbb{R}$, si empezamos en una posición inicial $x_0$, ¿en cuál dirección nos podríamos desplazar (por un paso chiquito) para ir hacia un mínimo?
#
# (ii) Impleméntalo, y dibuja la evolución en el tiempo del algoritmo, pintando la función como si fuera una colina, para distintas funciones.
#
# Este método se llama **descenso de gradiente**.

# %% [markdown]
# Si nos movemos en la dirección opuesta al gradiente de la función, ya que el gradiente es la dirección en la que la función incrementa más rápidamente, nos dirigiremos eficientemente hacia un mínimo de la función; si decidimos movernos en dirección del gradiente iremos hacia un máximo.

# %%
function descenso_gradiente(f:: Function, x0:: Number, pasito:: Real = 0.1 )
    i = 1
    datos = Number[x0]
    #push!(datos, x0)
    while abs(df(f,datos[i])) > 1e-6
        if i == 1000
            error("Límite de iteraciones.")
        end
        x0 = datos[i] - pasito*df(f,datos[i])
        push!(datos, x0)
        i += 1
    end
    return datos
end
# Out:
# descenso_gradiente (generic function with 2 methods)

# %%
descenso_gradiente(x -> (x-1)^2, 0.1)
# Out:
# 66-element Array{Number,1}:
#  0.1
#  0.28
#  0.424
#  0.5392
#  0.63136
#  0.705088
#  0.76407
#  0.811256
#  0.849005
#  0.879204
#  0.903363
#  0.922691
#  0.938152
#  ⋮
#  0.999995
#  0.999996
#  0.999997
#  0.999997
#  0.999998
#  0.999998
#  0.999999
#  0.999999
#  0.999999
#  0.999999
#  0.999999
#  1.0

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
function graficar_descenso(f :: Function, x0:: Number)
    puntos = descenso_gradiente(f, x0)
    xx = linspace(minimum(puntos)-.1,maximum(puntos)+.1,250)
    p = plot(xx,[f(x) for x in xx])
    for i in 1:length(puntos)
        p = plot!(xx,[f(x) for x in xx])
        scatter!([puntos[i]], [f(puntos[i])])
    end
    return p
end
# Out:
# graficar_descenso (generic function with 1 method)

# %%
graficar_descenso(x->(x-1)^2, 0.1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   46.6072,379.237 46.6072,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   289.086,379.237 289.086,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   531.564,379.237 531.564,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,374.168 587.581,374.168
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,194.444 587.581,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,14.7204 587.581,14.7204
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   46.6072,384.952 46.6072,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   289.086,384.952 289.086,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   531.564,384.952 531.564,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,374.168 39.0856,374.168
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,194.444 39.0856,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,14.7204 39.0856,14.7204
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 46.6072, 396.952)" x="46.6072" y="396.952">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 289.086, 396.952)" x="289.086" y="396.952">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 531.564, 396.952)" x="531.564" y="396.952">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 378.668)" x="29.4037" y="378.668">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 198.944)" x="29.4037" y="198.944">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 19.2204)" x="29.4037" y="19.2204">1.0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   46.6072,14.7204 48.7496,17.8893 50.892,21.0441 53.0344,24.1848 55.1768,27.3116 57.3191,30.4243 59.4615,33.523 61.6039,36.6076 63.7463,39.6782 65.8886,42.7348
#   68.031,45.7774 70.1734,48.8059 72.3158,51.8204 74.4582,54.8209 76.6005,57.8073 78.7429,60.7798 80.8853,63.7381 83.0277,66.6825 85.17,69.6128 87.3124,72.5291
#   89.4548,75.4314 91.5972,78.3196 93.7396,81.1938 95.8819,84.054 98.0243,86.9001 100.167,89.7322 102.309,92.5503 104.451,95.3544 106.594,98.1444 108.736,100.92
#   110.879,103.682 113.021,106.43 115.163,109.164 117.306,111.884 119.448,114.59 121.59,117.282 123.733,119.96 125.875,122.623 128.018,125.273 130.16,127.909
# [3] Podemos utilizar el descenso de gradiente también para buscar mínimos de funciones $f:\mathbb{R^n} \to \mathbb{R}$. Hazlo para algunas funciones $f:\mathbb{R}^2 \to \mathbb{R}$ y dibuja la evolución.
#
# Una versión estocástica del descenso de gradiente se utiliza mucho hoy día en aplicaciones de aprendizaje automático ("machine learning").

# %%
function gradiente(f :: Function, XY:: Vector{Float64}, h:: Real = 1e-8)
    gf = [(f( XY + [h,0]) - f(XY)) /h , (f(XY + [0,h]) - f(XY)) /h]
    return gf
end

function descenso_gradiente2(f:: Function, x0y0:: Vector{Float64}, pasito:: Real = 0.1 )
    i = 1
    datos = [x0y0]
    #push!(datos, x0)
    while norm(gradiente(f, datos[i])) > 1e-6
        if i == 1000
            error("Límite de iteraciones.")

        end
        x0y0 = datos[i] - pasito*gradiente(f,datos[i])
        push!(datos, x0y0)
        i += 1
    end
    return datos
end
# Out:
# descenso_gradiente2 (generic function with 2 methods)

# %%
g(XY) = (XY[1] - 1)^2 + sin(XY[2])
# Out:
# g (generic function with 1 method)

# %%
descenso_gradiente2(g, [0.1,2.])
# Out:
# 155-element Array{Array{Float64,1},1}:
#  [0.1,2.0]
#  [0.28,2.04161]
#  [0.424,2.08698]
#  [0.5392,2.13633]
#  [0.63136,2.18992]
#  [0.705088,2.24795]
#  [0.76407,2.31061]
#  [0.811256,2.37802]
#  [0.849005,2.45026]
#  [0.879204,2.5273]
#  [0.903363,2.60902]
#  [0.922691,2.69517]
#  [0.938152,2.78537]
#  ⋮
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]
#  [1.0,4.71239]

# %%
function graficar_descenso2(f :: Function, x0y0:: Vector{Float64})
    puntos = descenso_gradiente2(g, x0y0)
    M = zeros(length(puntos), 3)
    for i in 1:length(puntos)
        M[i,1] = puntos[i][1]
        M[i,2] = puntos[i][2]
        M[i,3] = g(puntos[i])
    end
    XX = linspace(minimum(M[:,1])-.1,maximum(M[:,1])+.1,100)
    YY = linspace(minimum(M[:,2])-.1,maximum(M[:,2])+.1,100)
    ZZ = [g([x,y]) for x in XX, y in YY]
    p = surface(XX,YY,ZZ)
    for i in 1:length(puntos)
        scatter3d!([M[i,1]],[M[i,2]],[M[i,3]])
    end
    return p
end

graficar_descenso2(g, [0.1,2.])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 12.8259,384.952 596.063,384.952 596.063,3.93701 12.8259,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="12" y="3" width="524" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,279.187 251.556,128.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.556,128.972 536.063,234.737
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,254.18 251.556,103.965
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.556,103.965 536.063,209.73
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,229.173 251.556,78.9579
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.556,78.9579 536.063,184.723
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,204.166 251.556,53.9509
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.556,53.9509 536.063,159.716
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,179.159 251.556,28.944
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.556,28.944 536.063,134.709
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,154.152 251.556,3.93701
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.556,3.93701 536.063,109.702
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   20.878,282.18 259.608,131.965
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.608,131.965 259.608,6.93035
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.8787,304.857 320.609,154.642
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   320.609,154.642 320.609,29.6072
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   142.879,327.534 381.609,177.319
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   381.609,177.319 381.609,52.284
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   203.88,350.211 442.61,199.996
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   442.61,199.996 442.61,74.9609
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   264.881,372.888 503.611,222.673
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   503.611,222.673 503.611,97.6377
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   27.3155,270.07 311.823,375.835
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   27.3155,270.07 27.3155,145.035
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   65.9808,245.741 350.488,351.505
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   65.9808,245.741 65.9808,120.706
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   104.646,221.411 389.153,327.176
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   104.646,221.411 104.646,96.3765
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   143.311,197.082 427.819,302.847
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   143.311,197.082 143.311,72.0472
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   181.977,172.753 466.484,278.518
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   181.977,172.753 181.977,47.718
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   220.642,148.424 505.149,254.188
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   220.642,148.424 220.642,23.3887
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   -2.17474,228.443 -3.25916,228.451 -3.98211,229.416 -4.34359,231.339 -4.34359,232.573 -3.98211,234.765 -3.25916,236.268 -2.17474,237.083 -1.45179,237.351 -0.367369,237.343
#   0.35558,236.377 0.717054,234.455 0.717054,233.22 0.35558,231.029 -0.367369,229.526 -1.45179,228.711 -2.17474,228.443
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   -3.98211,179.814 -3.98211,179.402 -3.62064,178.714 -3.25916,178.437 -2.53621,178.294 -1.09032,178.832 -0.367369,179.512 -0.0058944,180.058 0.35558,181.015 0.35558,181.838
#   -0.0058944,182.526 -0.728843,183.492 -4.34359,186.262 0.717054,188.144
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,279.187 12.8259,279.187 6.26907,283.313 12.8259,279.187 12.8259,254.18 9.54749,256.243 12.8259,254.18 12.8259,229.173 6.26907,233.299 12.8259,229.173
#   12.8259,204.166 9.54749,206.229 12.8259,204.166 12.8259,179.159 6.26907,183.285 12.8259,179.159 12.8259,154.152 9.54749,156.215 12.8259,154.152
#
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   1.71994,290.161 1.27598,290.826 1.87985,291.604 3.53153,292.495 4.68846,292.925 6.89321,293.468 8.60321,293.55 9.81845,293.172 10.3715,292.824 10.8155,292.158
#   10.2116,291.38 8.55992,290.489 7.40299,290.059 5.19824,289.516 3.48824,289.434 2.273,289.813 1.71994,290.161
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   115.425,340.735 114.981,341.4 115.585,342.178 117.237,343.069 118.394,343.499 120.599,344.042 122.309,344.124 123.524,343.745 124.077,343.397 124.521,342.732
#   123.917,341.954 122.265,341.063 121.108,340.633 118.904,340.09 117.194,340.008 115.978,340.387 115.425,340.735
#   "/>
# <polyline clip-p

# %% [markdown]
# ## Mínimos cuadrados

# %% [markdown]
# La optimización es muy imporante en la estadística. Por ejemplo, podemos utilizar optimización para resolver el problema de mínimos cuadrados, como sigue.

# %% [markdown]
# [4] Genera unos datos artificiales $(x_i, y_i)$ cerca de una recta, utilizando `rand()` para generar números aleatorios.

# %%
function datos_rand(m:: Real,b:: Real, n::Int64)
    datos = zeros(2,n)
    for i in 1:n
        datos[1,i] = (rand() - 0.5) #x_i
        datos[2,i] = m*datos[1,i] + (b + (rand() - 0.5)) #y_i
    end
    return datos
end
# Out:
# datos_rand (generic function with 1 method)

# %%
xy = datos_rand(5,1,20)
plot(x -> 5*x + 1, xlims=(-0.5,0.5))
scatter!(xy[1,:], xy[2,:])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.6037,379.237 30.6037,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   171.969,379.237 171.969,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   313.333,379.237 313.333,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   454.698,379.237 454.698,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,379.237 596.063,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,348.342 587.581,348.342
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,274.8 587.581,274.8
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,201.258 587.581,201.258
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,127.715 587.581,127.715
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,54.1726 587.581,54.1726
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   171.969,384.952 171.969,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   313.333,384.952 313.333,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   454.698,384.952 454.698,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,348.342 39.0856,348.342
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,274.8 39.0856,274.8
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,201.258 39.0856,201.258
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,127.715 39.0856,127.715
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,54.1726 39.0856,54.1726
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 30.6037, 396.952)" x="30.6037" y="396.952">-0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.969, 396.952)" x="171.969" y="396.952">-0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.333, 396.952)" x="313.333" y="396.952">0.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 454.698, 396.952)" x="454.698" y="396.952">0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 396.952)" x="596.063" y="396.952">0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 352.842)" x="29.4037" y="352.842">-20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 279.3)" x="29.4037" y="279.3">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 205.758)" x="29.4037" y="205.758">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 132.215)" x="29.4037" y="132.215">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 58.6726)" x="29.4037" y="58.6726">20</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   -2458.74,374.168 -1948.14,340.964 -1641.28,321.01 -1381.85,304.139 -1100.02,285.812 -840.204,268.917 -561.653,250.803 -238.924,229.816 47.8791,211.166 299.38,194.811
#   573.583,176.98 849.416,159.042 1154.38,139.211 1444.55,120.341 1746.26,100.721 2000.24,84.2056 2310.31,64.0418 2601.79,45.0872 3068.76,14.7204
#   "/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="398.273" cy="189.255" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#e9746a; stroke:none; fill-opacity:1" cx="398.273" cy="189.255" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="280.085" cy="199.243" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#e9746a; stroke:none; fill-opacity:1" cx="280.085" cy="199.243" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="463.941" cy="183.241" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#e9746a; stroke:none; fill-opacity:1" cx="463.941" cy="183.241" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:no

# %% [markdown]
# [5] Queremos ajustar una recta $\ell(x)$ a los datos.
#
# (i) ¿Cuántos parámetros necesitaremos ajustar. Escribe una fórmula para $\ell$ en términos de estos parámetros.
#
# (ii) En mínimos cuadrados, para cada punto $(x_i, y_i)$ calculamos la distancia cuadrada vertical desde la recta $\ell$. La suma de todos ellos nos da una **función de costo** o **función de pérdida**, la cual queremos minimizar con respecto a las variables de la recta.
#
# Formula esto matemáticamente: ¿cuál función queremos minimizar, y qué satisface el mínimo?

# %% [markdown]
# Queremos minimizar la función $S$, que nos da la suma de la distancia de cada punto (en términos de $(x,y)$) a la recta.
#
# $$ S = \sum_{i=1}^{n} r_{i}^2 $$,
#
# con
#
# $$r_i = (y_i - (m x_i +b))$$.
#
# Donde $y_i$ y $x_i$ son conocidos y $m,b$ son variables. Para esto necesitamos los valores de $m$ y $b$ tales que:
#
# $$\frac{\partial S}{\partial m}= 0$$ y $$\frac{\partial S}{\partial b}= 0$$.
#
# https://en.wikipedia.org/wiki/Least_squares .

# %% [markdown]
# [6] Utiliza el método de descenso de gradiente para resolver el problema. Dibuja el resultado - ¿es razonable? [Pista: Nota que tendrás que utilizar vectores (arreglos uni-dimensionales). En Julia, puedes operar con vectores utilizando operadores aritméticos, como si fueran vectores matemáticos.]

# %%
function minimos_cuadrados(datos:: Array)
    function S(recta:: Vector) #función de m y b
        suma = 0.0
        for i in 1:size(datos)[1]
            suma += (datos[2,i] -(recta[1]*datos[1,i] + recta[2]))^2
        end
        return suma
    end
    return recta_opt = descenso_gradiente2(S, rand(2))[end]
end
# Out:
# minimos_cuadrados (generic function with 1 method)

# %%
xy = datos_rand(5,1,20)
@show minimos_cuadrados(xy)
plot(x -> 5*x + 1, xlims=(-0.5,0.5), label="recta original")
scatter!(xy[1,:], xy[2,:], label="datos aleatorios")
plot!(x-> minimos_cuadrados(xy)[1]*x + minimos_cuadrados(xy)[2], label="recta ajustada")
# Out:
# minimos_cuadrados(xy) = [5.27901,1.42056]
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.6037,379.237 30.6037,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   171.969,379.237 171.969,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   313.333,379.237 313.333,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   454.698,379.237 454.698,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,379.237 596.063,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,348.342 587.581,348.342
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,274.8 587.581,274.8
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,201.258 587.581,201.258
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,127.715 587.581,127.715
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,54.1726 587.581,54.1726
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   171.969,384.952 171.969,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   313.333,384.952 313.333,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   454.698,384.952 454.698,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,348.342 39.0856,348.342
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,274.8 39.0856,274.8
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,201.258 39.0856,201.258
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,127.715 39.0856,127.715
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,54.1726 39.0856,54.1726
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 30.6037, 396.952)" x="30.6037" y="396.952">-0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.969, 396.952)" x="171.969" y="396.952">-0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.333, 396.952)" x="313.333" y="396.952">0.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 454.698, 396.952)" x="454.698" y="396.952">0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 396.952)" x="596.063" y="396.952">0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 352.842)" x="29.4037" y="352.842">-20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 279.3)" x="29.4037" y="279.3">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 205.758)" x="29.4037" y="205.758">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 132.215)" x="29.4037" y="132.215">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 58.6726)" x="29.4037" y="58.6726">20</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   -2458.74,374.168 -1948.14,340.964 -1641.28,321.01 -1381.85,304.139 -1100.02,285.812 -840.204,268.917 -561.653,250.803 -238.924,229.816 47.8791,211.166 299.38,194.811
#   573.583,176.98 849.416,159.042 1154.38,139.211 1444.55,120.341 1746.26,100.721 2000.24,84.2056 2310.31,64.0418 2601.79,45.0872 3068.76,14.7204
#   "/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="92.4995" cy="205.972" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#e9746a; stroke:none; fill-opacity:1" cx="92.4995" cy="205.972" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="447.363" cy="181.608" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#e9746a; stroke:none; fill-opacity:1" cx="447.363" cy="181.608" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="492.447" cy="185.906" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#e9746a; stroke:none; fill-opacity:1" cx="492.447" cy="185.906" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:no

# %% [markdown]
# Es suficientemente razonable.

# %% [markdown]
# ## Optimización con restricciones

# %% [markdown]
# [7] Utiliza un multiplicador de Lagrange para minimizar la función
# $f(x,y) = 2x+y$, sujeta a la **restricción** $x^2 + y^2 = 1$.
#
# Dibuja gráficamente lo que está pasando.

# %%
#:(
