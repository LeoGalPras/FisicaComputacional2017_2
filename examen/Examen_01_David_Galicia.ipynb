# %% [markdown]
# # Examen 1 - 27 febrero 2017

# %% [markdown]
# [1] En esta pregunta, escribiremos una función para calcular $\log(n!)$, es decir, el logaritmo del factorial de un número $n$.
#
# (i) Utiliza un bucle `for` para escribir una función `log_factorial` que toma un argumento `n` y que calcula el logaritmo del factorial de `n`. Para hacerlo, recuerda que el logaritmo de un producto es la suma de los logaritmos. [La función "logaritmo" en Julia se llama `log`.]

# %%
###(i)
function log_factorial(n::Real)
    logaritmo = 0.
   for i in 1:n
        logaritmo += log(i)
    end
    return logaritmo
end
    
log_factorial(4.)
# Out:
# 3.1780538303479453

# %%
log(factorial(4)) #coincide
# Out:
# 3.1780538303479458

# %% [markdown]
# (ii) Utiliza una comprensión de arreglo para calcular $\log(n!)$ para $n$ de 1 a 100.
#
# (iii) Dibuja esta cantidad en función de $n$. ¿Cualitativamente, cuál parece ser su tasa de crecimiento? ¿Qué implica esto sobre la tasa de crecimiento de $n!$?

# %%
using Plots
gr();

# %%
###(ii)
@show [log(i) for i in 1:100]
log_comprension = sum(log(i) for i in 1:100)
# Out:
# [log(i) for i = 1:100] = [0.0,0.693147,1.09861,1.38629,1.60944,1.79176,1.94591,2.07944,2.19722,2.30259,2.3979,2.48491,2.56495,2.63906,2.70805,2.77259,2.83321,2.89037,2.94444,2.99573,3.04452,3.09104,3.13549,3.17805,3.21888,3.2581,3.29584,3.3322,3.3673,3.4012,3.43399,3.46574,3.49651,3.52636,3.55535,3.58352,3.61092,3.63759,3.66356,3.68888,3.71357,3.73767,3.7612,3.78419,3.80666,3.82864,3.85015,3.8712,3.89182,3.91202,3.93183,3.95124,3.97029,3.98898,4.00733,4.02535,4.04305,4.06044,4.07754,4.09434,4.11087,4.12713,4.14313,4.15888,4.17439,4.18965,4.20469,4.21951,4.23411,4.2485,4.26268,4.27667,4.29046,4.30407,4.31749,4.33073,4.34381,4.35671,4.36945,4.38203,4.39445,4.40672,4.41884,4.43082,4.44265,4.45435,4.46591,4.47734,4.48864,4.49981,4.51086,4.52179,4.5326,4.54329,4.55388,4.56435,4.57471,4.58497,4.59512,4.60517]
# 363.7393755555636

# %%
##coincide con el valor utilizando factorial de julia
log(factorial(big(100)))
# Out:
# 3.637393755555634901440799933696556380278239210628872747276794488767759444479775e+02

# %%
###(iii)
logs_n = [log_factorial(i) for i in 1:100]
xx = [1:100]
scatter(xx,logs_n)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   41.2188,379.237 41.2188,9.65223
#   "/>
# ...

# %% [markdown]
# La gráfica parece dar una línea recta, sabemos que el crecimiento de $log(x)$ es logarítmico (¡Duh!), muy lento, pero al graficar $log(n!)$ tenemos una gráfica con pendiente mayor a 1, lo que nos dice que $n!$ crece más rápidamente de lo que decrece $log(x)$, (y el logaritmo decrece a la misma tasa que crece $e^x$) esto nos dice que $n!$ crece más rápidamente de $e^x$.

# %% [markdown]
# [2] Considera la suma de los cuadrados de los primeros $n$ enteros positivos,
#
# $$S_n := \sum_{i=1}^n i^2.$$
#
# Escriba una función que acepta un número $M$ y encuentra el valor mínimo de $n$ tal que $S_n > M$, es decir, tal que la suma exceda el valor dado.

# %%
function suma_mayor(M::Real)
    suma = 0
    i = 1
   while i < 10000 && suma < M
        suma += i^2
        i += 1
    end
    return i -1
end
# Out:
# suma_mayor (generic function with 1 method)

# %%
suma_mayor(100)
# Out:
# 7

# %%
#definimos la función con la fórmula analítica para verificar que funcione.
function suma_analitica(N)
suma = (N * (N + 1) * (2N + 1)) / 6
return suma
end
@show suma_analitica(6) #verificamos para una n debajo que dé una suma menor
@show suma_analitica(7) #y que la n que arroja dé una suma mayor;
# Out:
# suma_analitica(6) = 91.0
# suma_analitica(7) = 140.0

# %% [markdown]
# [3] (i) Escribe una función `f` que toma un valor de $x$ y calcula la serie
#
# $$f(x) = \sum_{n=1}^{\infty} \frac{x^n}{n}.$$
#
# Toma el número de términos $N(x)$ que sea necesario hasta que el tamaño del último término sea menor a una tolerancia.

# %%
function f(x::Real)
    n = 1
    x_n = 1.
    polinomio = Float64[]
    while n < 10000 && x_n > 1e-15 #ponemos un contador límite y una tolerancia
        x_n = (x^n)/n
        push!(polinomio,x_n)
        n += 1
    end
    serie = sum(polinomio)
    return serie
end
# Out:
# f (generic function with 1 method)

# %%
f(3)
# Out:
# 7.493103971664e14

# %% [markdown]
# (ii) Dibuja la función $f(x)$ en función de $x$, para $x$ de $-0.9$ a $0.9$.

# %%
rango = [-0.9:0.01:0.9]
datos = [f.(x) for x in rango]
scatter(rango,datos)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 12.8259,384.952 596.063,384.952 596.063,3.93701 12.8259,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="12" y="3" width="584" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   151.605,379.237 151.605,9.65223
#   "/>
# ...

# %% [markdown]
# (iii) Alguien sugiere que la función $f(x)$ podría ser realmente $-\log(1-x)$. ¿Qué deberías dibujar en función de qué para que salga una recta? Verifica que sí sea cierto.

# %%
#comparamos las dos funciones que sospechamos son iguales
scatter(rango,datos)
scatter!(rango,-log.(1 .-(rango)))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 12.8259,384.952 596.063,384.952 596.063,3.93701 12.8259,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="12" y="3" width="584" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   151.605,379.237 151.605,9.65223
#   "/>
# ...

# %% [markdown]
# Se separan en los negativos, pero podría ser error de cálculo, al acercarse al 1 se acercan las gráficas.

# %% [markdown]
# Separamos el dominio en los positivos y los negativos para poder tomar el valor absoluto y graficar en escala logarítmica X y Y.

# %%
rango2 = [0.01:0.01:0.9]
datos2 = [f.(x) for x in rango2]
scatter(rango2,datos2,yscale=:log10)
scatter!(rango2,-log.(1 .-(rango2)), yscale=:log10, xscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 66.1592,384.952 596.063,384.952 596.063,3.93701 66.1592,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="66" y="3" width="530" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   66.1592,379.237 66.1592,9.65223
#   "/>
# ...

# %%
rango3 = [-2:0.01:-0.01]
datos3 = [abs.(f.(x)) for x in rango3]
scatter(abs.(rango3), datos3, yscale=:log10, xscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 66.1592,384.952 596.063,384.952 596.063,3.93701 66.1592,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="66" y="3" width="530" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   66.1592,379.237 66.1592,9.65223
#   "/>
# ...

# %% [markdown]
# En escala log,log las gráficas dan una línea recta excepto cuando se acercan a 1, pero igual se pegan.
